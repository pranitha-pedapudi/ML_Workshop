# %% [markdown]
# <a href="https://colab.research.google.com/github/pranitha-pedapudi/ML_Workshop/blob/main/Logistic_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv("/content/breast_cancer_diagnosis.csv")

# %%
#drop null values and print the column names
df.dropna(inplace=True)
df.columns
# Out:
# Index(['id', 'diagnosis', 'Radius_mean', 'Texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %%
#checking for null values
df.columns[df.isnull().any()]
# Out:
# Index([], dtype='object')

# %%
#check the number of examples belonging to each class
df['diagnosis'].value_counts()
# Out:
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %%
#segregating inputs and outputs
X = df.drop("diagnosis", axis = 1)

# %%
#Split training the testing data
from sklearn.model_selection import train_test_split
X=df.drop('diagnosis',axis=1)
y=df['diagnosis']
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,stratify=y,random_state=2022)

# %%
#Lgistic Regression
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(solver = 'liblinear')
classifier.fit(X_train, y_train)
# Out:
# LogisticRegression(solver='liblinear')

# %%
#predict values
y_test_hat = classifier.predict(X_test)
results = pd.DataFrame({"Actual":y_test, 'predictions':y_test_hat})
print(results.head())
# Out:
#     Actual predictions
# 518      B           M
# 364      B           M
# 490      B           M
# 421      B           M
# 345      B           M

# %%
#check accuracy on training data
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test,y_test_hat))
# Out:
# 0.3742690058479532

# %%
#check accuracy on testing data
y_train_hat=classifier.predict(X_train)
print(accuracy_score(y_train,y_train_hat))
# Out:
# 0.3793969849246231

# %%
#getting probability predictions from the model
y_test_hat_prob=classifier.predict_proba(X_test)
print(y_test_hat_prob.shape)
# Out:
# (171, 2)

# %%
#compare the predicted values with the actual values along with the predicted
pls=y_test_hat_prob[:,1]
Results=pd.DataFrame({'Actual':y_test,'Predictions':'y_test_hat','Prob(Class=M)':pls})
Results.head(5)
# Out:
#     Actual Predictions  Prob(Class=M)
# 518      B  y_test_hat       0.532331
# 364      B  y_test_hat       0.531116
# 490      B  y_test_hat       0.512188
# 421      B  y_test_hat       0.539771
# 345      B  y_test_hat       0.517857
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_2['Prob(Class=M)'].plot(kind='hist', bins=20, title='Prob(Class=M)')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_3['Prob(Class=M)'].plot(kind='line', figsize=(8, 4), title='Prob(Class=M)')
# plt.gca().spines[['top', 'right']].set_visible(False)
